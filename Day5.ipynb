# %%
while True:
    num=int(input("Enter a number: "))
    print("You entered:", num)
    if num==10:
        print("Match 10")
        break
# Out:
# You entered: 12
# You entered: 1353
# You entered: 123134
# You entered: 10
# Match 10
