# %%
# File handling basics

# Writing to a file
with open('example.txt', 'w') as file:
    file.write('Hello, World!\n')
    file.write('This is a test file.')

# Reading from a file
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)

# Reading line by line
with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())

# Appending to a file
with open('example.txt', 'a') as file:
    file.write('\nAppended text.')
# Out:
# Hello, World!
# This is a test file.
# Hello, World!
# This is a test file.

# %%
#read a file

with open('hello.txt', 'r') as file:
    content=file.read()
    print(content)
# Out:
# Hello File Handling

# %%
#read a file 

data = open('hello.txt','r')
data.read()
# Out:
# 'Hello File Handling\n'

# %%
#update content in a file 

data = open('hello.txt','w')
data.write('My name is Aditya rao\n')
data = open('hello.txt','r')
data.read()
# Out:
# 'My name is Aditya rao\n'

# %%
#append
with open('hello.txt','a') as f:
    print(f.write("Btech 3rd yr student"))
# Out:
# 20

# %%
with open('hello.txt', 'r') as file:
    content=file.read()
    print(content)
# Out:
# My name is Aditya rao
# Btech 3rd yr student

# %%
#direct access csv file 
data1=open('file1.csv','r')
print(data1.read())
# Out:
# name,roll no
# dheeraj,123
# kunal,1234
# abhishek,12345
# praveen,12356
# anjali,1234567

# %% [markdown]
# Numpy

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\aditya rao\anaconda3\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
