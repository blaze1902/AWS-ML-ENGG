# %%
print("Aditya rao")
# Out:
# Aditya rao

# %%
#variable

num=10
print(num)
print(id(num))

num1=10
print(num1)
print(id(num1))

print(type(num))
print(type(num1))
# Out:
# 10
# 140736058078408
# 10
# 140736058078408
# <class 'int'>
# <class 'int'>

# %%
roll_no=int(input("enter the roll no "))  #explicit
print(roll_no)
print(id(roll_no))
print(type(roll_no))


#str(),float(),bool()

a=input("enter the value of a ")
print(a)
print(type(a))
b=bool(input("enter the value of b "))
print(b)
print(type(b))
c=float(input("enter the value of c "))
print(c)
print(type(c))
# Out:
# 13
# 140736058078504
# <class 'int'>
# aditya
# <class 'str'>
# True
# <class 'bool'>
# 13.2
# <class 'float'>
